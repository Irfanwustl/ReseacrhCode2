# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Replace this with the path to your file
file_path = '/logo2/irfan/Bladder2/BWA_output_Arpit_motifs_4.txt'

# Read the data
# Assuming your data is tab-separated; if it's comma-separated, use sep=',' instead
df = pd.read_csv(file_path, sep='\t', index_col=0)

# Calculate total counts for each sample (column)
total_counts = df.sum(axis=0)

# Normalize to Counts Per Million (CPM)
df_cpm = df.divide(total_counts, axis=1) * 1e6

display(df_cpm.head())
# Out:
#       NU3_UC1.dup_mk_motifs.txt  WBC1255_UC1.dup_mk_motifs.txt  \
# AAAA               15477.198396                   15118.663649
# AAAC                4748.573905                    4769.491845
# AAAG                6066.599797                    6135.852412
# AAAT                8208.962546                    8496.881266
# AACA                5290.994965                    5690.955178
#
#       NU1_UC1.dup_mk_motifs.txt  NU33_UC1.dup_mk_motifs.txt  \
# AAAA               15695.554867                14871.529222
# AAAC                4970.482189                 4692.759676
# AAAG                6312.535091                 5939.241726
# AAAT                8524.800261                 7918.746801
# AACA                5808.150676                 5216.694888
#
#       NU19R_UC1.dup_mk_motifs.txt  WBC1071_UC1.dup_mk_motifs.txt  \
# AAAA                 16279.303309                   14647.215833
# AAAC                  4688.235017                    4681.525029
# AAAG                  6016.572498                    5956.946101
# AAAT                  8069.759432                    7198.249586
# AACA                  5483.213772                    4961.535384
#
#       WBC1277_UC1.dup_mk_motifs.txt  WBC1203_UC1.dup_mk_motifs.txt  \
# AAAA                   15562.465518                   16027.303261
# AAAC                    4866.251573                    4375.925380
# AAAG                    6461.503876                    5664.849069
# AAAT                    8773.212109                    7517.751824
# AACA                    5570.616128                    5269.366172
#
#       BC015_UC1.dup_mk_motifs.txt  WBC1298_UC1.dup_mk_motifs.txt  ...  \
# AAAA                 16804.303849                   15692.382777  ...
# AAAC                  4664.174945                    4987.569612  ...
# AAAG                  6494.975119                    6081.406209  ...
# AAAT                  8117.556636                    8632.198118  ...
# AACA                  5324.492678                    6022.718312  ...
#
#       WBC1196_UC1.dup_mk_motifs.txt  WBC1111_UC1.dup_mk_motifs.txt  \
# AAAA                   16040.447341                   16512.243450
# AAAC                    4615.870369                    4737.650658
# AAAG                    5916.432546                    6036.326282
# AAAT                    8045.194565                    8336.090809
# AACA                    5384.544363                    5609.713655
#
#       NU16_UC1.dup_mk_motifs.txt  NU70_UC1.dup_mk_motifs.txt  \
# AAAA                13174.504640                15533.059024
# AAAC                 4380.985643                 4684.934800
# AAAG                 5696.302818                 6041.067470
# AAAT                 7202.979328                 8076.549516
# AACA                 5105.314467                 5219.126359
#
#       WBC1188_UC1.dup_mk_motifs.txt  BC016_UC1.dup_mk_motifs.txt  \
# AAAA                   15466.595564                 16522.333166
# AAAC                    4440.229560                  4100.526419
# AAAG                    5992.893554                  5524.167824
# AAAT                    7538.394064                  6961.778124
# AACA                    5261.055474                  5036.908625
#
#       WBC1309_UC1.dup_mk_motifs.txt  WBC1304_UC1.dup_mk_motifs.txt  \
# AAAA                   15618.621409                   15207.783048
# AAAC                    4893.263004                    4419.213859
# AAAG                    6407.153684                    5833.054080
# AAAT                    8482.257057                    7497.263065
# AACA                    5571.634024                    5400.128270
#
#       WBC1322_UC1.dup_mk_motifs.txt  BC011_UC1.dup_mk_motifs.txt
# AAAA                   14980.897685                 13390.838743
# AAAC                    4300.654611                  3861.307287
# AAAG                    5598.575085                  5121.731616
# AAAT                    6950.091489                  5838.191156
# AACA                    5161.847975                  4874.397555
#
# [5 rows x 64 columns]

# %%
# Log transformation with a small constant to avoid log(0)
df_log = np.log2(df_cpm + 1)
# Compute Z-scores for the motifs across samples
df_zscore = df_log.apply(lambda x: (x - x.mean()) / x.std(), axis=1)

# %%
df_log.head()
# Out:
#       NU3_UC1.dup_mk_motifs.txt  WBC1255_UC1.dup_mk_motifs.txt  \
# AAAA                  13.917950                      13.884138
# AAAC                  12.213582                      12.219922
# AAAG                  12.566910                      12.583283
# AAAT                  13.003160                      13.052887
# AACA                  12.369596                      12.474709
#
#       NU1_UC1.dup_mk_motifs.txt  NU33_UC1.dup_mk_motifs.txt  \
# AAAA                  13.938160                   13.860362
# AAAC                  12.279460                   12.196528
# AAAG                  12.624232                   12.536306
# AAAT                  13.057620                   12.951239
# AACA                  12.504112                   12.349197
#
#       NU19R_UC1.dup_mk_motifs.txt  WBC1071_UC1.dup_mk_motifs.txt  \
# AAAA                    13.990840                      13.838437
# AAAC                    12.195137                      12.193071
# AAAG                    12.554966                      12.540599
# AAAT                    12.978489                      12.813631
# AACA                    12.421069                      12.276862
#
#       WBC1277_UC1.dup_mk_motifs.txt  WBC1203_UC1.dup_mk_motifs.txt  \
# AAAA                      13.925876                      13.968334
# AAAC                      12.248892                      12.095702
# AAAG                      12.657878                      12.468076
# AAAT                      13.099054                      12.876277
# AACA                      12.443880                      12.363687
#
#       BC015_UC1.dup_mk_motifs.txt  WBC1298_UC1.dup_mk_motifs.txt  ...  \
# AAAA                    14.036629                      13.937869  ...
# AAAC                    12.187715                      12.284410  ...
# AAAG                    12.665330                      12.570426  ...
# AAAT                    12.987008                      13.075679  ...
# AACA                    12.378699                      12.556439  ...
#
#       WBC1196_UC1.dup_mk_motifs.txt  WBC1111_UC1.dup_mk_motifs.txt  \
# AAAA                      13.969517                      14.011336
# AAAC                      12.172700                      12.210261
# AAAG                      12.530756                      12.559694
# AAAT                      12.974091                      13.025328
# AACA                      12.394876                      12.453969
#
#       NU16_UC1.dup_mk_motifs.txt  NU70_UC1.dup_mk_motifs.txt  \
# AAAA                   13.685571                   13.923147
# AAAC                   12.097369                   12.194121
# AAAG                   12.476063                   12.560827
# AAAT                   12.814578                   12.979702
# AACA                   12.318067                   12.349869
#
#       WBC1188_UC1.dup_mk_motifs.txt  BC016_UC1.dup_mk_motifs.txt  \
# AAAA                      13.916961                    14.012217
# AAAC                      12.116743                    12.001945
# AAAG                      12.549278                    12.431803
# AAAT                      12.880233                    12.765447
# AACA                      12.361411                    12.298609
#
#       WBC1309_UC1.dup_mk_motifs.txt  WBC1304_UC1.dup_mk_motifs.txt  \
# AAAA                      13.931072                      13.892617
# AAAC                      12.256876                      12.109900
# AAAG                      12.645693                      12.510283
# AAAT                      13.050403                      12.872341
# AACA                      12.444144                      12.399045
#
#       WBC1322_UC1.dup_mk_motifs.txt  BC011_UC1.dup_mk_motifs.txt
# AAAA                      13.870933                    13.709066
# AAAC                      12.070676                    11.915247
# AAAG                      12.451102                    12.322698
# AAAT                      12.763024                    12.511553
# AACA                      12.333951                    12.251304
#
# [5 rows x 64 columns]

# %%
df_zscore.head()
# Out:
#       NU3_UC1.dup_mk_motifs.txt  WBC1255_UC1.dup_mk_motifs.txt  \
# AAAA                  -0.072120                      -0.399393
# AAAC                   0.582943                       0.644051
# AAAG                   0.327619                       0.486710
# AAAT                   0.540408                       0.901893
# AACA                  -0.120083                       1.241819
#
#       NU1_UC1.dup_mk_motifs.txt  NU33_UC1.dup_mk_motifs.txt  \
# AAAA                   0.123503                   -0.629529
# AAAC                   1.217913                    0.418565
# AAAG                   0.884602                    0.030245
# AAAT                   0.936292                    0.162976
# AACA                   1.622782                   -0.384386
#
#       NU19R_UC1.dup_mk_motifs.txt  WBC1071_UC1.dup_mk_motifs.txt  \
# AAAA                     0.633407                      -0.841749
# AAAC                     0.405154                       0.385242
# AAAG                     0.211559                       0.071963
# AAAT                     0.361066                      -0.837337
# AACA                     0.546834                      -1.321605
#
#       WBC1277_UC1.dup_mk_motifs.txt  WBC1203_UC1.dup_mk_motifs.txt  \
# AAAA                       0.004597                       0.415565
# AAAC                       0.923274                      -0.553257
# AAAG                       1.211523                      -0.632722
# AAAT                       1.237491                      -0.381939
# AACA                       0.842387                      -0.196637
#
#       BC015_UC1.dup_mk_motifs.txt  WBC1298_UC1.dup_mk_motifs.txt  ...  \
# AAAA                     1.076615                       0.120681  ...
# AAAC                     0.333622                       1.265626  ...
# AAAG                     1.283941                       0.361785  ...
# AAAT                     0.422992                       1.067575  ...
# AACA                    -0.002135                       2.300763  ...
#
#       WBC1196_UC1.dup_mk_motifs.txt  WBC1111_UC1.dup_mk_motifs.txt  \
# AAAA                       0.427012                       0.831794
# AAAC                       0.188890                       0.550926
# AAAG                      -0.023685                       0.257501
# AAAT                       0.329097                       0.701557
# AACA                       0.207466                       0.973099
#
#       NU16_UC1.dup_mk_motifs.txt  NU70_UC1.dup_mk_motifs.txt  \
# AAAA                   -2.321397                   -0.021813
# AAAC                   -0.537190                    0.395364
# AAAG                   -0.555115                    0.268506
# AAAT                   -0.830449                    0.369885
# AACA                   -0.787728                   -0.375678
#
#       WBC1188_UC1.dup_mk_motifs.txt  BC016_UC1.dup_mk_motifs.txt  \
# AAAA                      -0.081689                     0.840324
# AAAC                      -0.350448                    -1.456941
# AAAG                       0.156289                    -0.985185
# AAAT                      -0.353186                    -1.187598
# AACA                      -0.226136                    -1.039830
#
#       WBC1309_UC1.dup_mk_motifs.txt  WBC1304_UC1.dup_mk_motifs.txt  \
# AAAA                       0.054892                      -0.317325
# AAAC                       1.000232                      -0.416405
# AAAG                       1.093130                      -0.222612
# AAAT                       0.883830                      -0.410557
# AACA                       0.845802                       0.261477
#
#       WBC1322_UC1.dup_mk_motifs.txt  BC011_UC1.dup_mk_motifs.txt
# AAAA                      -0.527215                    -2.093973
# AAAC                      -0.794473                    -2.292587
# AAAG                      -0.797661                    -2.045328
# AAAT                      -1.205215                    -3.033235
# AACA                      -0.581916                    -1.652743
#
# [5 rows x 64 columns]

# %%
# Read the Excel file
pCR_info_df = pd.read_excel('/logo2/irfan/Bladder2/ULP-WGS 65 samples clinical sheet_irf.xlsx',sheet_name='irf')

# Create a dictionary to map Sample IDs to their pCR status
pCR_dict = pd.Series(pCR_info_df['pCR (1= pCR, No pCR=0)'].values, index=pCR_info_df['Sample ID']).to_dict()

# Function to remove the suffix and return the label
def get_label(sample_id, pCR_dict):
    # Remove the .dup_mk_motifs.txt suffix to match with the Excel file
    sample_id = sample_id.replace('.dup_mk_motifs.txt', '')
    if sample_id.startswith('NU'):
        return 'Healthy'
    else:
        return 'pCR' if pCR_dict.get(sample_id, 0) == 1 else 'No pCR'

# Prepare labels for the heatmap and PCA
labels = [get_label(sample_id, pCR_dict) for sample_id in df_zscore.columns]

# Convert labels to a color palette
unique_labels = set(labels)
palette = sns.color_palette("husl", len(unique_labels))
# Define the colors for each label
label_colors = {'Healthy': 'green', 'pCR': 'blue', 'No pCR': 'red'}
row_colors = [label_colors[label] for label in labels]

# %%
labels[:10]
# Out:
# ['Healthy',
#  'pCR',
#  'Healthy',
#  'Healthy',
#  'Healthy',
#  'No pCR',
#  'pCR',
#  'pCR',
#  'No pCR',
#  'pCR']

# %%
unique_labels
# Out:
# {'Healthy', 'No pCR', 'pCR'}

# %%
#row_colors

# %%
import matplotlib.patches as mpatches

# Create the seaborn clustermap with updated labels
g = sns.clustermap(df_zscore, method='average', cmap='bwr', center=0,
                   row_cluster=True, col_cluster=True, 
                   col_colors=row_colors, figsize=(8,8),  # Adjust the size as needed
                   xticklabels=1, yticklabels=1)

# Set the labels for the axes
g.ax_heatmap.set_xlabel('Samples', fontsize=12)
g.ax_heatmap.set_ylabel('Motifs', fontsize=12)

# Set the label for the color bar
g.cax.set_title('Motif frequency\n(Z-score)', fontsize=10)


# Create legend handles with the specified colors
legend_handles = [mpatches.Patch(color=color, label=label) for label, color in label_colors.items()]



# Add the legend to the figure with the specified colors
g.ax_col_dendrogram.legend(handles=legend_handles, title='Sample Type', loc='center', bbox_to_anchor=(1.3, 0.6), ncol=len(label_colors))


# Rotate the x-axis labels if needed
plt.setp(g.ax_heatmap.get_xticklabels(), rotation=90)

# Rotate the y-axis labels if needed
plt.setp(g.ax_heatmap.get_yticklabels(), rotation=0)
plt.setp( plt.gcf().axes, xticks=[], yticks=[])

# Show the plot
plt.show()
# Out:
# /home/ialahi/anaconda3/envs/jupyter_lab_2/lib/python3.8/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
# /home/ialahi/anaconda3/envs/jupyter_lab_2/lib/python3.8/site-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1

# %%
# Extract the indices of the rows and columns as ordered in the clustermap
# These indices correspond to the new order after clustering
row_order = g.dendrogram_row.reordered_ind
column_order = g.dendrogram_col.reordered_ind

# Use the indices to reorder the original DataFrame
clustered_df = df_zscore.iloc[row_order, column_order]
clustered_df.columns
# Out:
# Index(['WBC1300_UC1.dup_mk_motifs.txt', 'WBC1222__UC1.dup_mk_motifs.txt',
#        'WBC1320_UC1.dup_mk_motifs.txt', 'WBC1071_UC1.dup_mk_motifs.txt',
#        'NU16_UC1.dup_mk_motifs.txt', 'WBC1171_UC1.dup_mk_motifs.txt',
#        'WBC1313_UC1.dup_mk_motifs.txt', 'WBC1186_UC1.dup_mk_motifs.txt',
#        'WBC1206_UC1.dup_mk_motifs.txt', 'BC020_UC1.dup_mk_motifs.txt',
#        'NU36_UC1.dup_mk_motifs.txt', 'WBC1317_UC1.dup_mk_motifs.txt',
#        'NU19_UC1.dup_mk_motifs.txt', 'NU3_UC1.dup_mk_motifs.txt',
#        'NU32_UC1.dup_mk_motifs.txt', 'NU33_UC1.dup_mk_motifs.txt',
#        'NU70_UC1.dup_mk_motifs.txt', 'NU18_UC1.dup_mk_motifs.txt',
#        'NU71_UC1.dup_mk_motifs.txt', 'WBC1314_UC1.dup_mk_motifs.txt',
#        'WBC1277_UC1.dup_mk_motifs.txt', 'WBC1132_UC1.dup_mk_motifs.txt',
#        'WBC1133_UC1.dup_mk_motifs.txt', 'WBC1303_UC1.dup_mk_motifs.txt',
#        'WBC1242_UC1.dup_mk_motifs.txt', 'WBC1233_UC1.dup_mk_motifs.txt',
#        'WBC1298_UC1.dup_mk_motifs.txt', 'NU1_UC1.dup_mk_motifs.txt',
#        'WBC1197_UC1.dup_mk_motifs.txt', 'WBC1309_UC1.dup_mk_motifs.txt',
#        'WBC1322_UC1.dup_mk_motifs.txt', 'WBC1147_UC1.dup_mk_motifs.txt',
#        'WBC1304_UC1.dup_mk_motifs.txt', 'WBC1109_UC1.dup_mk_motifs.txt',
#        'WBC1111_UC1.dup_mk_motifs.txt', 'BC009_UC1.dup_mk_motifs.txt',
#        'BC006_UC1.dup_mk_motifs.txt', 'BC005_UC1.dup_mk_motifs.txt',
#        'WBC1188_UC1.dup_mk_motifs.txt', 'BC015_UC1.dup_mk_motifs.txt',
#        'WBC1085_UC1.dup_mk_motifs.txt', 'WBC1050_UC1.dup_mk_motifs.txt',
#        'NU19R_UC1.dup_mk_motifs.txt', 'WBC1064_UC1.dup_mk_motifs.txt',
#        'WBC1310_UC1.dup_mk_motifs.txt', 'WBC1185__UC1.dup_mk_motifs.txt',
#        'WBC1196_UC1.dup_mk_motifs.txt', 'WBC1269_UC1.dup_mk_motifs.txt',
#        'BC011_UC1.dup_mk_motifs.txt', 'WBC1315_UC1.dup_mk_motifs.txt',
#        'WBC1096_UC1.dup_mk_motifs.txt', 'BC016_UC1.dup_mk_motifs.txt',
#        'WBC1076_UC1.dup_mk_motifs.txt', 'WBC1083_UC1.dup_mk_motifs.txt',
#        'WBC1063_UC1.dup_mk_motifs.txt', 'WBC1311_UC1.dup_mk_motifs.txt',
#        'NU68_UC1.dup_mk_motifs.txt', 'WBC1312_UC1.dup_mk_motifs.txt',
#        'WBC1203_UC1.dup_mk_motifs.txt', 'WBC1088_UC1.dup_mk_motifs.txt',
#        'WBC1291_UC1.dup_mk_motifs.txt', 'BC021_UC1.dup_mk_motifs.txt',
#        'WBC1255_UC1.dup_mk_motifs.txt', 'NU75_UC1.dup_mk_motifs.txt'],
#       dtype='object')

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Initialize PCA model
pca = PCA(n_components=2)  # for 2D projection

# Perform PCA on the Z-score normalized data
pca_result = pca.fit_transform(df_zscore.T)  # transpose to get samples as rows

# Create a DataFrame with the PCA results
pca_df = pd.DataFrame(pca_result, columns=['PC1', 'PC2'])

# If you have labels for each sample (e.g., healthy or cancer), you can color the points accordingly
# Here's an example if you have a list or array of labels corresponding to the samples order in df_zscore
#labels = np.array(['Healthy' if 'NU' in sample else 'Cancer' for sample in df_zscore.columns])

# Plot the PCA
plt.figure(figsize=(8, 8))
sns.scatterplot(x='PC1', y='PC2', hue=labels, data=pca_df, palette=label_colors)
plt.title('PCA of Motif Frequencies')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend(title='Sample Type')
plt.show()

# %% [markdown]
# # MDS

# %%
total_cpm = df_cpm.sum(axis=0)  # Sum of CPMs for each sample
relative_frequencies = df_cpm.divide(total_cpm, axis=1)  # Convert CPM to relative frequencies
relative_frequencies.sum()
# Out:
# NU3_UC1.dup_mk_motifs.txt        1.0
# WBC1255_UC1.dup_mk_motifs.txt    1.0
# NU1_UC1.dup_mk_motifs.txt        1.0
# NU33_UC1.dup_mk_motifs.txt       1.0
# NU19R_UC1.dup_mk_motifs.txt      1.0
#                                 ...
# BC016_UC1.dup_mk_motifs.txt      1.0
# WBC1309_UC1.dup_mk_motifs.txt    1.0
# WBC1304_UC1.dup_mk_motifs.txt    1.0
# WBC1322_UC1.dup_mk_motifs.txt    1.0
# BC011_UC1.dup_mk_motifs.txt      1.0
# Length: 64, dtype: float64

# %%
print(np.finfo(float).eps)
print(1-np.finfo(float).eps)
# Out:
# 2.220446049250313e-16
# 0.9999999999999998

# %%
# Replace any potential zero values with a very small number to avoid log2(0)
relative_frequencies = relative_frequencies.replace(0, np.finfo(float).eps)

# Now you can calculate the MDS
MDS = -np.sum(relative_frequencies * np.log2(relative_frequencies), axis=0) / np.log2(df_cpm.shape[0])

# %%
MDS.head()
# Out:
# NU3_UC1.dup_mk_motifs.txt        0.975597
# WBC1255_UC1.dup_mk_motifs.txt    0.965773
# NU1_UC1.dup_mk_motifs.txt        0.971723
# NU33_UC1.dup_mk_motifs.txt       0.976665
# NU19R_UC1.dup_mk_motifs.txt      0.972990
# dtype: float64

# %%
# Step 1: Assign MDS to Each Sample
# Assuming the 'MDS' variable contains the calculated MDS values for each sample as a pandas Series
MDS_dataframe = pd.DataFrame(MDS, columns=['MDS_Value'])

# Step 2: Map Samples to Groups
# Using the previously defined 'get_label' function and 'pCR_dict'
group_labels = [get_label(sample_id, pCR_dict) for sample_id in MDS_dataframe.index]

# Add the group labels to the MDS DataFrame
MDS_dataframe['Group'] = group_labels
MDS_dataframe.head()
# Out:
#                                MDS_Value    Group
# NU3_UC1.dup_mk_motifs.txt       0.975597  Healthy
# WBC1255_UC1.dup_mk_motifs.txt   0.965773      pCR
# NU1_UC1.dup_mk_motifs.txt       0.971723  Healthy
# NU33_UC1.dup_mk_motifs.txt      0.976665  Healthy
# NU19R_UC1.dup_mk_motifs.txt     0.972990  Healthy

# %%
MDS_dataframe
# Out:
#                                MDS_Value    Group
# NU3_UC1.dup_mk_motifs.txt       0.975597  Healthy
# WBC1255_UC1.dup_mk_motifs.txt   0.965773      pCR
# NU1_UC1.dup_mk_motifs.txt       0.971723  Healthy
# NU33_UC1.dup_mk_motifs.txt      0.976665  Healthy
# NU19R_UC1.dup_mk_motifs.txt     0.972990  Healthy
# ...                                  ...      ...
# BC016_UC1.dup_mk_motifs.txt     0.971332   No pCR
# WBC1309_UC1.dup_mk_motifs.txt   0.972203      pCR
# WBC1304_UC1.dup_mk_motifs.txt   0.971886   No pCR
# WBC1322_UC1.dup_mk_motifs.txt   0.973351   No pCR
# BC011_UC1.dup_mk_motifs.txt     0.973872   No pCR
#
# [64 rows x 2 columns]

# %%
import pandas as pd
import numpy as np
from scipy.stats import mannwhitneyu
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'MDS_dataframe' has 'MDS_Value' and 'Group' columns and is ready for plotting
# Here we should already have the MDS values in the dataframe along with the group labels.

# Mann-Whitney U test function
def perform_mwu_test(group1, group2, data):
    group1_data = data[data['Group'] == group1]['MDS_Value']
    group2_data = data[data['Group'] == group2]['MDS_Value']
    u_stat, p_value = mannwhitneyu(group1_data, group2_data, alternative='two-sided')
    return p_value

# Calculate p-values
p_healthy_pcr = perform_mwu_test('Healthy', 'pCR', MDS_dataframe)
p_healthy_no_pcr = perform_mwu_test('Healthy', 'No pCR', MDS_dataframe)
p_pcr_no_pcr = perform_mwu_test('pCR', 'No pCR', MDS_dataframe)

# Plot the boxplot
plt.figure(figsize=(10, 6))
ax = sns.boxplot(x='Group', y='MDS_Value', data=MDS_dataframe, palette="Set2")

# Calculate the max y-value for the plot to place the annotations
y_max = MDS_dataframe['MDS_Value'].max()
y_offset = y_max * 0.001  # Dynamic offset based on the max y-value

# Define x-positions for each group for the annotations
x_positions = {'Healthy': 0, 'pCR': 1, 'No pCR': 2}

# Calculate p-values and store them with their respective group pairs
p_values = {
    ('Healthy', 'pCR'): p_healthy_pcr,
    ('Healthy', 'No pCR'): p_healthy_no_pcr,
    ('pCR', 'No pCR'): p_pcr_no_pcr
}

# Draw the connectors and annotations
for (group1, group2), p_value in p_values.items():
    x1, x2 = x_positions[group1], x_positions[group2]
    # Set the y position for the line
    y = y_max + y_offset * (1 + x_positions[group2] - x_positions[group1])
    # Draw line
    ax.plot([x1, x1, x2, x2], [y, y + y_offset, y + y_offset, y], lw=1.5, c='k')
    # Annotate line with p-value
    ax.text((x1+x2)*.5, y + y_offset, f"p={p_value:.3f}", ha='center', va='bottom', color='k')

# Set y-axis limit to include annotations
ax.set_ylim(ax.get_ylim()[0], y + y_offset * 3)

plt.title('Boxplot of MDS by Group with p-values')
plt.xlabel('Group')
plt.ylabel('MDS Value')
plt.show()

# %%
# Copy the original MDS_dataframe to a new variable
MDS_combined = MDS_dataframe.copy()

# Modify the 'Group' labels in the new dataframe to combine 'pCR' and 'No pCR' into 'Cancer'
MDS_combined['Group'] = MDS_combined['Group'].replace({'pCR': 'Cancer', 'No pCR': 'Cancer'})

# Perform the Mann-Whitney U test between 'Healthy' and 'Cancer'
healthy_mds = MDS_combined[MDS_combined['Group'] == 'Healthy']['MDS_Value']
cancer_mds = MDS_combined[MDS_combined['Group'] == 'Cancer']['MDS_Value']
u_stat, p_value = mannwhitneyu(healthy_mds, cancer_mds, alternative='two-sided')

# Plot the boxplot
plt.figure(figsize=(10, 6))
ax = sns.boxplot(x='Group', y='MDS_Value', data=MDS_combined, palette="Set2")

# Calculate the max and min y-value for the plot to place the annotations and to set the limits
y_max = MDS_combined['MDS_Value'].max()
y_min = MDS_combined['MDS_Value'].min()
y_range = y_max - y_min
y_offset = 0.01 * y_range  # Offset for annotations based on the range

# Draw the connector and the p-value annotation
x1, x2 = 0, 1  # positions for 'Healthy' and 'Cancer'
plt.plot([x1, x1, x2, x2], [y_max + y_offset, y_max + 2 * y_offset, y_max + 2 * y_offset, y_max + y_offset], lw=1.5, c='k')
plt.text((x1+x2)*0.5, y_max + 2 * y_offset, f"p={p_value:.3f}", ha='center', va='bottom', color='k')

# Set the y-axis limit to make the plot more readable, focusing on the box plots
upper_limit = y_max + 10 * y_offset
lower_limit = y_min - 2 * y_offset
plt.ylim(lower_limit, upper_limit)

plt.title('Boxplot of MDS for Healthy vs Cancer with p-value')
plt.xlabel('Group')
plt.ylabel('MDS Value')
plt.show()
